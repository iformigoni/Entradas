# %% [markdown]
# <a href="https://colab.research.google.com/github/iformigoni/Entrada_Publica/blob/main/sans%C3%A3o_no_gueto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Samson in the Ghetto-Arthur Szyk.jpg](data:image/jpeg;base64,...)
